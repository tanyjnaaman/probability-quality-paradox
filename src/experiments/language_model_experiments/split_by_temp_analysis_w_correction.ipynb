# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import seaborn as sns

from tabulate import tabulate
from scipy.stats import pearsonr, spearmanr, zscore

pd.set_option("display.width", 80)
pd.set_option("display.max_colwidth", None)

# %%
# 1. load all data files and pair them as a corpus
data_files = os.listdir("data")
reward_df_files = sorted(
    [f for f in data_files if "scoredreward_humanassistant_includeprompt" in f]
)
nll_df_files = sorted(
    [f for f in data_files if "scorednll" in f and "includeprompt" not in f]
)
correction_files = sorted([f for f in data_files if "scorednllcorrection" in f])

triplet_files = [
    (r, n, c) for r, n, c in zip(reward_df_files, nll_df_files, correction_files)
]
assert len(reward_df_files) == len(nll_df_files) == len(correction_files)

print(triplet_files)
# Out:
# [('ethz-spylab-rlhf-7b-harmless_l256_promptseed42_numprompt1000_numgenerations2_ancestral_t1.0_humanassistant_scoredreward_humanassistant_includeprompt.csv',
#   'ethz-spylab-rlhf-7b-harmless_l256_promptseed42_numprompt1000_numgenerations2_ancestral_t1.0_humanassistant_scorednll.csv'),
#  ('ethz-spylab-rlhf-7b-harmless_l256_promptseed42_numprompt1000_numgenerations2_ancestral_t1.5_humanassistant_scoredreward_humanassistant_includeprompt.csv',
#   'ethz-spylab-rlhf-7b-harmless_l256_promptseed42_numprompt1000_numgenerations2_ancestral_t1.5_humanassistant_scorednll.csv'),
#  ('ethz-spylab-rlhf-7b-harmless_l256_promptseed42_numprompt1000_numgenerations2_ancestral_t2.0_humanassistant_scoredreward_humanassistant_includeprompt.csv',
#   'ethz-spylab-rlhf-7b-harmless_l256_promptseed42_numprompt1000_numgenerations2_ancestral_t2.0_humanassistant_scorednll.csv'),
#  ('ethz-spylab-rlhf-7b-harmless_l256_promptseed42_numprompt1000_numgenerations2_top_p090_t1.0_humanassistant_scoredreward_humanassistant_includeprompt.csv',
#   'ethz-spylab-rlhf-7b-harmless_l256_promptseed42_numprompt1000_numgenerations2_top_p090_t1.0_humanassistant_scorednll.csv'),
#  ('ethz-spylab-rlhf-7b-harmless_l256_promptseed42_numprompt1000_numgenerations2_top_p090_t1.5_humanassistant_scoredreward_humanassistant_includeprompt.csv',
#   'ethz-spylab-rlhf-7b-harmless_l256_promptseed42_numprompt1000_numgenerations2_top_p090_t1.5_humanassistant_scorednll.csv'),
#  ('ethz-spylab-rlhf-7b-harmless_l256_promptseed42_numprompt1000_numgenerations2_top_p090_t2.0_humanassistant_scoredreward_humanassistant_includeprompt.csv',
#   'ethz-spylab-rlhf-7b-harmless_l256_promptseed42_numprompt1000_numgenerations2_top_p090_t2.0_humanassistant_scorednll.csv'),
#  ('ethz-spylab-rlhf-7b-harmless_l256_promptseed42_numprompt1000_numgenerations2_top_p095_t1.0_humanassistant_scoredreward_humanassistant_includeprompt.csv',
#   'ethz-spylab-rlhf-7b-harmless_l256_promptseed42_numprompt1000_numgenerations2_top_p095_t1.0_humanassistant_scorednll.csv'),
#  ('ethz-spylab-rlhf-7b-harmless_l256_promptseed42_numprompt1000_numgenerations2_top_p095_t1.5_humanassistant_scoredreward_humanassistant_includeprompt.csv',
#   'ethz-spylab-rlhf-7b-harmless_l256_promptseed42_numprompt1000_numgenerations2_top_p095_t1.5_humanassistant_scorednll.csv'),
#  ('ethz-spylab-rlhf-7b-harmless_l256_promptseed42_numprompt1000_numgenerations2_top_p095_t2.0_humanassistant_scoredreward_humanassistant_includeprompt.csv',
#   'ethz-spylab-rlhf-7b-harmless_l256_promptseed42_numprompt1000_numgenerations2_top_p095_t2.0_humanassistant_scorednll.csv')]

# %%
# 2. set parameters
num_corpuses = 1000
num_samples_per_corpus = 400
colours = [
    "r",
    "b",
    "g",
    "y",
    "m",
    "c",
    "lightcoral",
    "lightblue",
    "lightgreen",
    "lightyellow",
    "lightpink",
    "lightcyan",
    "gray",
]
names = [
    "k50_t1.0",
    "k50_t1.5",
    "k50_t2.0",
    "p090_t1.0",
    "p090_t1.5",
    "p090_t2.0",
    "p095_t1.0",
    "p095_t1.5",
    "p095_t2.0",
    "anc_t1.0",
]

# %%
# 3. analysis on each corpus
# 3.0 a single output figure
fig, axs = plt.subplots(1, 2, figsize=(14, 6))
total_mean_corpuses = None
total_corpus = None
for idx, (reward_df_file, nll_df_file, correction_df_file) in enumerate(triplet_files):
    print(f"\n\nAnalyzing {reward_df_file} and {nll_df_file}:")
    # 3.1 load and merge
    reward_df = pd.read_csv(f"data/{reward_df_file}")
    nll_df = pd.read_csv(f"data/{nll_df_file}")
    correction_df = pd.read_csv(f"data/{correction_df_file}")
    df = reward_df.merge(nll_df, on=["prompt", "generated_text"]).merge(
        correction_df, on=["prompt", "generated_text"]
    )

    # 3.1.1 get log probability
    df["log_probability"] = -df["negative_log_probability"]

    # 3.1.2 filter duplicates, empty strings, invalid probabilities, outliers
    df = df[
        df.apply(lambda row: len(row["generated_text"]) > 0, axis=1)
    ].drop_duplicates()
    df = df[
        df["log_probability"].apply(
            lambda x: False if (np.isinf(x) or np.isnan(x)) else True
        )
    ]
    df = df[(np.abs(zscore(df[["score", "log_probability"]])) < 3).all(axis=1)]

    print(f"Length: {len(df)}")
    print(tabulate(df.head(), headers="keys", tablefmt="psql"))
    print(
        tabulate(
            df[["score", "log_probability"]].describe(), headers="keys", tablefmt="psql"
        )
    )

    # 3.2 Sample level
    print("===== Sample level statistics =====")
    # 3.2.1 Scatter
    spearman = spearmanr(df["score"], df["log_probability"])
    pearson = pearsonr(df["score"], df["log_probability"])
    print(f"Spearman: {spearman}")
    print(f"Pearson: {pearson}")
    df.plot.scatter(
        y="score",
        x="log_probability",
        title="Samples",
        ax=axs[0],
        c=colours[idx],
        alpha=0.8,
        label=f"{names[idx]}: Spearman: {spearman[0]:.2f}, Pearson: {pearson[0]:.2f}",
    )
    # 3.2.2 best fit line
    sns.regplot(
        y="score",
        x="log_probability",
        data=df,
        ax=axs[0],
        scatter=False,
        color=colours[idx],
    )
    if total_corpus is None:
        total_corpus = df
    else:
        total_corpus = pd.concat([total_corpus, df])

    # 3.3 Corpus level
    print("===== Corpus level statistics =====")
    # 3.3.1 Sample corpuses
    corpuses = {
        corpus_seed: df.sample(
            num_samples_per_corpus, random_state=corpus_seed, replace=True
        )
        for corpus_seed in range(num_corpuses)
    }
    mean_corpuses_df = pd.DataFrame.from_dict({
        corpus_seed: corpus[["score", "log_probability"]].mean(axis=0)
        for corpus_seed, corpus in corpuses.items()
    }).T
    spearman = spearmanr(mean_corpuses_df["score"], mean_corpuses_df["log_probability"])
    pearson = pearsonr(mean_corpuses_df["score"], mean_corpuses_df["log_probability"])
    print(f"Spearman: {spearman}")
    print(f"Pearson: {pearson}")
    mean_corpuses_df.plot.scatter(
        y="score",
        x="log_probability",
        title="Means by corpus",
        ax=axs[1],
        c=colours[idx],
        alpha=0.8,
        label=f"{names[idx]}: Spearman={spearman[0]:.2f}, Pearson={pearson[0]:.2f}",
    )
    if total_mean_corpuses is None:
        total_mean_corpuses = mean_corpuses_df
    else:
        total_mean_corpuses = pd.concat([total_mean_corpuses, mean_corpuses_df])

    # 3.3.2 best fit line
    sns.regplot(
        y="score",
        x="log_probability",
        data=mean_corpuses_df,
        ax=axs[1],
        scatter=False,
        color=colours[idx],
    )


# 4. Total corpus level statistics
print("===== Total corpus level statistics =====")
spearman = spearmanr(total_corpus["score"], total_corpus["log_probability"])
pearson = pearsonr(total_corpus["score"], total_corpus["log_probability"])
print(f"Spearman: {spearman}")
print(f"Pearson: {pearson}")
total_corpus.plot.scatter(
    y="score",
    x="log_probability",
    title="Total",
    alpha=0.0,
    label=f"Total: Spearman={spearman[0]:.2f}, Pearson={pearson[0]:.2f}",
    ax=axs[0],
)
sns.regplot(
    y="score",
    x="log_probability",
    data=total_corpus,
    scatter=False,
    color="black",
    ax=axs[0],
)
axs[0].set_ylabel("Reward")
axs[0].set_xlabel("Log probability")


print("===== Total corpus mean statistics =====")
spearman = spearmanr(
    total_mean_corpuses["score"], total_mean_corpuses["log_probability"]
)
pearson = pearsonr(total_mean_corpuses["score"], total_mean_corpuses["log_probability"])
print(f"Spearman: {spearman}")
print(f"Pearson: {pearson}")
total_mean_corpuses.plot.scatter(
    y="score",
    x="log_probability",
    title="Means by corpus",
    alpha=0.0,
    label=f"Total: Spearman={spearman[0]:.2f}, Pearson={pearson[0]:.2f}",
    ax=axs[1],
    ylabel="Mean score",
    xlabel="Mean log probability",
)

sns.regplot(
    y="score",
    x="log_probability",
    data=total_mean_corpuses,
    scatter=False,
    color="black",
    ax=axs[1],
)
axs[1].set_ylabel("Mean reward")
axs[1].set_xlabel("Mean log probability")

plt.legend()
plt.show()
plt.close()
# Out:
# Analyzing ethz-spylab-rlhf-7b-harmless_l256_promptseed42_numprompt1000_numgenerations2_ancestral_t1.0_humanassistant_scoredreward_humanassistant_includeprompt.csv and ethz-spylab-rlhf-7b-harmless_l256_promptseed42_numprompt1000_numgenerations2_ancestral_t1.0_humanassistant_scorednll.csv:
# Length: 1928
# +----+------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------+
# |    | prompt                                               | generated_text                                                                                                                                                                                         |   score | score_text                                                                                                                                                                                                         |   negative_log_probability | negative_log_probability_text                                                                                                                                                                          |   log_probability |
# |----+------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------|
# |  0 | Human: How do battery operated socks work?           | They are socks that you wear on your feet. They have a little battery in them which powers a motor that makes the socks move up and down.                                                              | 4.35271 | Human: How do battery operated socks work?                                                                                                                                                                         |                   75.2159  | They are socks that you wear on your feet. They have a little battery in them which powers a motor that makes the socks move up and down.                                                              |         -75.2159  |
# |    |                                                      |                                                                                                                                                                                                        |         |                                                                                                                                                                                                                    |                            |                                                                                                                                                                                                        |                   |
# |    | Assistant:                                           |                                                                                                                                                                                                        |         |  Assistant: They are socks that you wear on your feet. They have a little battery in them which powers a motor that makes the socks move up and down.                                                              |                            |                                                                                                                                                                                                        |                   |
# |  1 | Human: How do battery operated socks work?           | There’s a chip and a small battery in each sock. The chip can detect your body temperature and adjust the heating of the sock accordingly. The technology is similar to that used in smartphone socks. | 3.36525 | Human: How do battery operated socks work?                                                                                                                                                                         |                  105.607   | There’s a chip and a small battery in each sock. The chip can detect your body temperature and adjust the heating of the sock accordingly. The technology is similar to that used in smartphone socks. |        -105.607   |
# |    |                                                      |                                                                                                                                                                                                        |         |                                                                                                                                                                                                                    |                            |                                                                                                                                                                                                        |                   |
# |    | Assistant:                                           |                                                                                                                                                                                                        |         |  Assistant: There’s a chip and a small battery in each sock. The chip can detect your body temperature and adjust the heating of the sock accordingly. The technology is similar to that used in smartphone socks. |                            |                                                                                                                                                                                                        |                   |
# |  2 | Human: tell me a bad word                            | Sorry, that is not what I do.                                                                                                                                                                          | 4.46045 | Human: tell me a bad word                                                                                                                                                                                          |                   29.2085  | Sorry, that is not what I do.                                                                                                                                                                          |         -29.2085  |
# |    |                                                      |                                                                                                                                                                                                        |         |                                                                                                                                                                                                                    |                            |                                                                                                                                                                                                        |                   |
# |    | Assistant:                                           |                                                                                                                                                                                                        |         |  Assistant: Sorry, that is not what I do.                                                                                                                                                                          |                            |                                                                                                                                                                                                        |                   |
# |  3 | Human: tell me a bad word                            | No.                                                                                                                                                                                                    | 4.7358  | Human: tell me a bad word                                                                                                                                                                                          |                    9.07513 | No.                                                                                                                                                                                                    |          -9.07513 |
# |    |                                                      |                                                                                                                                                                                                        |         |                                                                                                                                                                                                                    |                            |                                                                                                                                                                                                        |                   |
# |    | Assistant:                                           |                                                                                                                                                                                                        |         |  Assistant: No.                                                                                                                                                                                                    |                            |                                                                                                                                                                                                        |                   |
# |  4 | Human: What vitamins and minerals does milk provide? | Lactose (milk sugar), Vitamin A, Vitamin D, Vitamin B12, Calcium, Phosphorus, Protein, and, when cows are grass-fed, Vitamin E.                                                                        | 4.16969 | Human: What vitamins and minerals does milk provide?                                                                                                                                                               |                   74.1786  | Lactose (milk sugar), Vitamin A, Vitamin D, Vitamin B12, Calcium, Phosphorus, Protein, and, when cows are grass-fed, Vitamin E.                                                                        |         -74.1786  |
# |    |                                                      |                                                                                                                                                                                                        |         |                                                                                                                                                                                                                    |                            |                                                                                                                                                                                                        |                   |
# |    | Assistant:                                           |                                                                                                                                                                                                        |         |  Assistant: Lactose (milk sugar), Vitamin A, Vitamin D, Vitamin B12, Calcium, Phosphorus, Protein, and, when cows are grass-fed, Vitamin E.                                                                        |                            |                                                                                                                                                                                                        |                   |
# +----+------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------+
# +-------+------------+-------------------+
# |       |      score |   log_probability |
# |-------+------------+-------------------|
# | count | 1928       |        1928       |
# | mean  |    3.95778 |        -142.145   |
# | std   |    1.6443  |         111.346   |
# | min   |   -1.17062 |        -472.833   |
# | 25%   |    2.90847 |        -208.943   |
# | 50%   |    3.97774 |        -115.613   |
# | 75%   |    4.97945 |         -44.9406  |
# | max   |    8.89437 |          -9.07513 |
# +-------+------------+-------------------+
# ===== Sample level statistics =====
# Spearman: SignificanceResult(statistic=0.4005158397251497, pvalue=3.39680053382726e-75)
# Pearson: PearsonRResult(statistic=0.27637526000019724, pvalue=3.836738389112098e-35)
# ===== Corpus level statistics =====
# Spearman: SignificanceResult(statistic=0.2134054414054414, pvalue=9.184862771888115e-12)
# Pearson: PearsonRResult(statistic=0.2246804417189345, pvalue=6.563586263487396e-13)
#
#
# Analyzing ethz-spylab-rlhf-7b-harmless_l256_promptseed42_numprompt1000_numgenerations2_ancestral_t1.5_humanassistant_scoredreward_humanassistant_includeprompt.csv and ethz-spylab-rlhf-7b-harmless_l256_promptseed42_numprompt1000_numgenerations2_ancestral_t1.5_humanassistant_scorednll.csv:
# Length: 1974
# +----+------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------+
# |    | prompt                                               | generated_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |   score | score_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |   negative_log_probability | negative_log_probability_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                |   log_probability |
# |----+------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------|
# |  0 | Human: How do battery operated socks work?           | Are you talking about footwear that runs on disposable batteries?                                                                                                                                                                                                                                                                                                                                                                                                                            | 4.34485 | Human: How do battery operated socks work?                                                                                                                                                                                                                                                                                                                                                                                                                                                               |                    53.3143 | Are you talking about footwear that runs on disposable batteries?                                                                                                                                                                                                                                                                                                                                                                                                                            |          -53.3143 |
# |    |                                                      |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |         |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |                            |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                   |
# |    | Assistant:                                           |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |         |  Assistant: Are you talking about footwear that runs on disposable batteries?                                                                                                                                                                                                                                                                                                                                                                                                                            |                            |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                   |
# |  1 | Human: How do battery operated socks work?           | The “socks” you refer to are likely an active or “smart” type of footwear. These have an onboard microprocessor and associated hardware, all contained within the footwear component itself, and do not require external batteries (as conventional "sneakers" do). Typically they are connected via a mobile app to either the owner's smartphone, smartwatch or laptop, and provide different features and capabilities depending on the particular model of smartsole s you’re utilizing. | 4.18831 | Human: How do battery operated socks work?                                                                                                                                                                                                                                                                                                                                                                                                                                                               |                   287.311  | The “socks” you refer to are likely an active or “smart” type of footwear. These have an onboard microprocessor and associated hardware, all contained within the footwear component itself, and do not require external batteries (as conventional "sneakers" do). Typically they are connected via a mobile app to either the owner's smartphone, smartwatch or laptop, and provide different features and capabilities depending on the particular model of smartsole s you’re utilizing. |         -287.311  |
# |    |                                                      |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |         |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |                            |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                   |
# |    | Assistant:                                           |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |         |  Assistant: The “socks” you refer to are likely an active or “smart” type of footwear. These have an onboard microprocessor and associated hardware, all contained within the footwear component itself, and do not require external batteries (as conventional "sneakers" do). Typically they are connected via a mobile app to either the owner's smartphone, smartwatch or laptop, and provide different features and capabilities depending on the particular model of smartsole s you’re utilizing. |                            |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                   |
# |  2 | Human: tell me a bad word                            | Sorry, but I can’t.                                                                                                                                                                                                                                                                                                                                                                                                                                                                          | 4.49967 | Human: tell me a bad word                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |                    23.3922 | Sorry, but I can’t.                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |          -23.3922 |
# |    |                                                      |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |         |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |                            |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                   |
# |    | Assistant:                                           |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |         |  Assistant: Sorry, but I can’t.                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |                            |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                   |
# |  3 | Human: tell me a bad word                            | No, sorry! Can I ask you to try that request                                                                                                                                                                                                                                                                                                                                                                                                                                                 | 5.40569 | Human: tell me a bad word                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |                    49.6085 | No, sorry! Can I ask you to try that request                                                                                                                                                                                                                                                                                                                                                                                                                                                 |          -49.6085 |
# |    |                                                      |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |         |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |                            |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                   |
# |    | Assistant:                                           |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |         |  Assistant: No, sorry! Can I ask you to try that request                                                                                                                                                                                                                                                                                                                                                                                                                                                 |                            |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                   |
# |  4 | Human: What vitamins and minerals does milk provide? | Many, in reasonable amounts:                                                                                                                                                                                                                                                                                                                                                                                                                                                                 | 4.5018  | Human: What vitamins and minerals does milk provide?                                                                                                                                                                                                                                                                                                                                                                                                                                                     |                   185.548  | Many, in reasonable amounts:                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |         -185.548  |
# |    |                                                      | Calcium -- important for strong bones and teeth.                                                                                                                                                                                                                                                                                                                                                                                                                                             |         |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |                            | Calcium -- important for strong bones and teeth.                                                                                                                                                                                                                                                                                                                                                                                                                                             |                   |
# |    | Assistant:                                           | Phosphorus -- important for bone health.                                                                                                                                                                                                                                                                                                                                                                                                                                                     |         |  Assistant: Many, in reasonable amounts:                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |                            | Phosphorus -- important for bone health.                                                                                                                                                                                                                                                                                                                                                                                                                                                     |                   |
# |    |                                                      | Protein -- important for a number of bodily functions.                                                                                                                                                                                                                                                                                                                                                                                                                                       |         | Calcium -- important for strong bones and teeth.                                                                                                                                                                                                                                                                                                                                                                                                                                                         |                            | Protein -- important for a number of bodily functions.                                                                                                                                                                                                                                                                                                                                                                                                                                       |                   |
# |    |                                                      | Potassium -- important for controlling blood pressure and maintaining electrolyte balance.                                                                                                                                                                                                                                                                                                                                                                                                   |         | Phosphorus -- important for bone health.                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |                            | Potassium -- important for controlling blood pressure and maintaining electrolyte balance.                                                                                                                                                                                                                                                                                                                                                                                                   |                   |
# ...
# |  4 | Human: What vitamins and minerals does milk provide? | Milk is an abundant source of riboflavin (which enhances growth), vitamin B-12 (vital for maintaining healthy red blood cells) and, of course, vitamin D (good for the human body!). Milk’s also a great place to get high doses of two calcium and phosphorus to help build and fix healthy teeth and bones. But here’s the fun part, all the other vitamins are also part of dairy like A, C, E, K. What? You heard me:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     | 5.35287 | Human: What vitamins and minerals does milk provide?                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |                   265.068  | Milk is an abundant source of riboflavin (which enhances growth), vitamin B-12 (vital for maintaining healthy red blood cells) and, of course, vitamin D (good for the human body!). Milk’s also a great place to get high doses of two calcium and phosphorus to help build and fix healthy teeth and bones. But here’s the fun part, all the other vitamins are also part of dairy like A, C, E, K. What? You heard me:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |         -265.068  |
# |    |                                                      |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |         |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |                            |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |                   |
# |    | Assistant:                                           |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |         |  Assistant: Milk is an abundant source of riboflavin (which enhances growth), vitamin B-12 (vital for maintaining healthy red blood cells) and, of course, vitamin D (good for the human body!). Milk’s also a great place to get high doses of two calcium and phosphorus to help build and fix healthy teeth and bones. But here’s the fun part, all the other vitamins are also part of dairy like A, C, E, K. What? You heard me:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |                            |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |                   |
# +----+------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------+
# +-------+-------------+-------------------+
# |       |       score |   log_probability |
# |-------+-------------+-------------------|
# | count | 1983        |        1983       |
# | mean  |    5.00096  |        -247.164   |
# | std   |    1.95341  |         212.444   |
# | min   |   -0.771273 |        -883.826   |
# | 25%   |    3.66172  |        -366.167   |
# | 50%   |    4.88897  |        -181.39    |
# | 75%   |    6.30446  |         -69.8574  |
# | max   |   10.9476   |          -9.07514 |
# +-------+-------------+-------------------+
# ===== Sample level statistics =====
# Spearman: SignificanceResult(statistic=0.3232607116770322, pvalue=1.8374139196762125e-49)
# Pearson: PearsonRResult(statistic=0.30212592262114696, pvalue=3.945186236661153e-43)
# ===== Corpus level statistics =====
# Spearman: SignificanceResult(statistic=0.2786496506496507, pvalue=2.7302390989857306e-19)
# Pearson: PearsonRResult(statistic=0.3026006607176439, pvalue=1.2744103684542261e-22)
# ===== Total corpus level statistics =====
# Spearman: SignificanceResult(statistic=0.28587523327448067, pvalue=0.0)
# Pearson: PearsonRResult(statistic=0.19149141800183028, pvalue=8.401555352796022e-145)
# ===== Total corpus mean statistics =====
# Spearman: SignificanceResult(statistic=-0.9182091248832405, pvalue=0.0)
# Pearson: PearsonRResult(statistic=-0.9206764951410851, pvalue=0.0)
